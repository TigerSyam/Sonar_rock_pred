# %% [markdown]
# ## SONAR_PREDICTION

# %% [markdown]
# ## Description:

# %% [markdown]
# ### Objective:
# Developed a machine learning model to classify whether an object detected by sonar is a rock or a mine.

# %% [markdown]
# ### Tools Used:
# Programming Language: Python
#
# Libraries: Pandas, NumPy, Scikit-learn, Matplotlib

# %% [markdown]
# ### Approach:

# %% [markdown]
# ##### Data Preprocessing:
#
# Cleaned and normalized the sonar dataset to prepare it for modeling.
# Split the dataset into training and testing subsets.

# %% [markdown]
# ##### Model Building:
#
# Experimented with classification algorithms such as Logistic Regression, K-Nearest Neighbors, and Support Vector Machines.
# Tuned hyperparameters using GridSearchCV to optimize performance.

# %% [markdown]
# ##### Evaluation:
#
# Evaluated the model's performance using metrics like accuracy, precision, recall, and F1-score.
# Visualized the decision boundaries for better understanding.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#loading dataset into pandas dataFrame
data=pd.read_csv("C:\\Users\\Tiger Syam\\Desktop\\IBM coursera\\SuperwisedML-Classification\\Projects\\Sonar_rock_pred_Logistic_pro1\\datasets\\sonar data.csv",header=None)

# %%
dataset=data.copy()

# %%
data
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    float64
#  1   1       208 non-null    float64
#  2   2       208 non-null    float64
#  3   3       208 non-null    float64
#  4   4       208 non-null    float64
#  5   5       208 non-null    float64
#  6   6       208 non-null    float64
#  7   7       208 non-null    float64
#  8   8       208 non-null    float64
#  9   9       208 non-null    float64
#  10  10      208 non-null    float64
#  11  11      208 non-null    float64
#  12  12      208 non-null    float64
#  13  13      208 non-null    float64
#  14  14      208 non-null    float64
#  15  15      208 non-null    float64
#  16  16      208 non-null    float64
#  17  17      208 non-null    float64
#  18  18      208 non-null    float64
#  19  19      208 non-null    float64
# ...

# %%
data.describe()   #describes the statistical methods of the data
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
from sklearn.metrics import precision_recall_fscore_support

# %%
def get_accuracy(X_train,X_test,y_train,y_test,model):
    
    result={}
    y_pred=model.predict(X_test)
    accuracy=accuracy_score(y_test,y_pred)
    result['accuracy']=accuracy
    precision,recall,f_score,_=precision_recall_fscore_support(y_test,y_pred)
    
    result['precision']=precision
    result['recall']=recall
    result['f_score']=f_score
    
    return result

# %%
data[60].unique()
# Out:
# array(['R', 'M'], dtype=object)

# %%
#marking our target column as target
data=data.rename(columns={60:'target'})
data.head()
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#         9  ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  target
# 0  0.0090  0.0032       R
# 1  0.0052  0.0044       R
# ...

# %%
data['target'].value_counts(normalize=True)   #our both classes are balanced
# Out:
# M    0.533654
# R    0.466346
# Name: target, dtype: float64

# %% [markdown]
# M->Mine
#
# R->ROck
#
# here ,our target variable has two classes one is rock and oother is mine ....
# lets replace rock with '0' and mine with '1'....

# %%
df=data[['target']]
df['target']=(df['target']=='M').astype(int)
# Out:
# C:\Users\Tiger Syam\AppData\Local\Temp\ipykernel_1760\1126155346.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target']=(df['target']=='M').astype(int)

# %%
data['target']=(data['target']=='M').astype(int)

# %%
data['target'].value_counts()    # 1 -> Mine
                                 # 0 -> Rock
# Out:
# 1    111
# 0     97
# Name: target, dtype: int64

# %%
data.head()
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#         9  ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  target
# 0  0.0090  0.0032       0
# 1  0.0052  0.0044       0
# ...

# %% [markdown]
# #### Train/Test Split

# %% [markdown]
# below ,separating our target and labels

# %%
X=data.iloc[:,:-1]
y=data['target']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 203    1
# 204    1
# 205    1
# 206    1
# 207    1
# Name: target, Length: 208, dtype: int32

# %%
#import train_test_split
from sklearn.model_selection import train_test_split

# %%
#separating our data into train and test sets
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=123)

# %% [markdown]
# ### Logistic Model

# %% [markdown]
# since our classes are binary ....lets first start with logistic Regression

# %%
#import our logistic regression model
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# lets ,go with simple logistic model.....now

# %%
lg=LogisticRegression()
lg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lg.predict(X_test)

# %% [markdown]
# #### Model Evaluation

# %%
#accuracy Score

# %%
print(get_accuracy(X_train,X_test,y_train,y_test,lg))
# Out:
# {'accuracy': 0.7380952380952381, 'precision': array([0.77777778, 0.70833333]), 'recall': array([0.66666667, 0.80952381]), 'f_score': array([0.71794872, 0.75555556])}

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7619047619047619

# %%
y_train_pred=model.predict(X_train)
accuracy_score(y_train,y_train_pred)
# Out:
# 0.8433734939759037

# %% [markdown]
# #### GridSearchCV

# %% [markdown]
# its seems to be accuracy 0.73 its not bad....but we need to improve it

# %%
from sklearn.model_selection import GridSearchCV

# %%
params_grid={'penalty':['l1','l2','elasticnet'],
             'solver':['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
             'C':[0.01,0.02,0.05,0.07,0.1,0.5,0.8,1,5,10],
             'max_iter':[50,100,200,500,1000,1100]
            }

# %%
search=GridSearchCV(estimator=lg,param_grid=params_grid,scoring='accuracy')
search.fit(X_train,y_train)
# Out:
# C:\Users\Tiger Syam\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Tiger Syam\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Tiger Syam\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Tiger Syam\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
search.best_params_
# Out:
# {'C': 5, 'max_iter': 50, 'penalty': 'l2', 'solver': 'lbfgs'}

# %%
search.best_score_
# Out:
# 0.8007130124777184

# %%
model=LogisticRegression(C=5,penalty='l2',solver='lbfgs',max_iter=50)
model=model.fit(X_train,y_train)

# %%
y_pred=model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7380952380952381

# %%
get_accuracy(X_train,X_test,y_train,y_test,model)
# Out:
# {'accuracy': 0.7380952380952381,
#  'precision': array([0.77777778, 0.70833333]),
#  'recall': array([0.66666667, 0.80952381]),
#  'f_score': array([0.71794872, 0.75555556])}

# %% [markdown]
# #### Making Predictive Sysyem

# %%
input_data=(0.0192,0.0607,0.0378,0.0774,0.1388,0.0809,0.0568,0.0219,0.1037,0.1186,0.1237,0.1601,0.3520,0.4479,0.3769,0.5761,0.6426,0.6790,0.7157,0.5466,0.5399,0.6362,0.7849,0.7756,0.5780,0.4862,0.4181,0.2457,0.0716,0.0613,0.1816,0.4493,0.5976,0.3785,0.2495,0.5771,0.8852,0.8409,0.3570,0.3133,0.6096,0.6378,0.2709,0.1419,0.1260,0.1288,0.0790,0.0829,0.0520,0.0216,0.0360,0.0331,0.0131,0.0120,0.0108,0.0024,0.0045,0.0037,0.0112,0.0075)

#changing the input data to a numpy array 

input_data_as_numpy_array=np.asarray(input_data)

input_data_reshaped =input_data_as_numpy_array.reshape(1,-1)

prediction =lg.predict(input_data_reshaped)
print(prediction)

if(prediction[0]==0):
    
    print('The object is a Rock')
else:
    print('The object is a mine')
# Out:
# [0]
# The object is a Rock
